# %%
import pandas as pd

# %%
#funcao read_csv
df = pd.read_csv("/Users/moreira/Desktop/Ciencia_Dados_2026.1/Unidade I/Dataset/gapminder.csv"
                 , delimiter=",")
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %% [markdown]
# ### Dicionário de Dados - Dataset - Gapminder
#
# - Country (country). Describes the country name
# - Continent (continent). Describes the continent to which the country belongs
# - Year (year). Describes the year to which the data belongs
# - Life expectancy (life_exp). Describes the life expectancy for a given country in a given year
# - Gross Domestic Product per capita (gdp). Describes the GDP per capita in dollars for a given country in a given year

# %%
df.head(30) #primeiras linhas
# Out:
#         country continent  year  lifeExp       pop    gdpPercap
# 0   Afghanistan      Asia  1952   28.801   8425333   779.445314
# 1   Afghanistan      Asia  1957   30.332   9240934   820.853030
# 2   Afghanistan      Asia  1962   31.997  10267083   853.100710
# 3   Afghanistan      Asia  1967   34.020  11537966   836.197138
# 4   Afghanistan      Asia  1972   36.088  13079460   739.981106
# 5   Afghanistan      Asia  1977   38.438  14880372   786.113360
# 6   Afghanistan      Asia  1982   39.854  12881816   978.011439
# 7   Afghanistan      Asia  1987   40.822  13867957   852.395945
# 8   Afghanistan      Asia  1992   41.674  16317921   649.341395
# 9   Afghanistan      Asia  1997   41.763  22227415   635.341351
# 10  Afghanistan      Asia  2002   42.129  25268405   726.734055
# 11  Afghanistan      Asia  2007   43.828  31889923   974.580338
# 12      Albania    Europe  1952   55.230   1282697  1601.056136
# 13      Albania    Europe  1957   59.280   1476505  1942.284244
# ...

# %%
df.tail(10) #ultimas linhas
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1694  Zimbabwe    Africa  1962   52.358   4277736  527.272182
# 1695  Zimbabwe    Africa  1967   53.995   4995432  569.795071
# 1696  Zimbabwe    Africa  1972   55.635   5861135  799.362176
# 1697  Zimbabwe    Africa  1977   57.674   6642107  685.587682
# 1698  Zimbabwe    Africa  1982   60.363   7636524  788.855041
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
print(type(df)) #tipo de estrutura de dados
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.shape #observe a quanti. de linhas e colunas
# Out:
# (1704, 6)

# %%
df.columns #nomes das colunas
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
df.dtypes #obter o dtype de cada coluna (tipo de dado)
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %%
df.info() #mais informacoes dos dados, como dados ausentes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
country_df = df["country"] #obtem somente a coluna country
country_df
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
country_df.head()
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
subset = df[["country", "continent", "year"]]
subset.tail()
# Out:
#        country continent  year
# 1699  Zimbabwe    Africa  1987
# 1700  Zimbabwe    Africa  1992
# 1701  Zimbabwe    Africa  1997
# 1702  Zimbabwe    Africa  2002
# 1703  Zimbabwe    Africa  2007

# %%
#iloc e loc
#.loc permite fazer a selecao utilizando diretamente os rotulos do dataframe
#.iloc acessar a partir da sua posicao(indice)

# %%
subset.iloc[1:3] #selecionar as linhas com uso do indice
# Out:
#        country continent  year
# 1  Afghanistan      Asia  1957
# 2  Afghanistan      Asia  1962

# %%
subset.iloc[50:300, 0:2]
# Out:
#        country continent
# 50   Argentina  Americas
# 51   Argentina  Americas
# 52   Argentina  Americas
# 53   Argentina  Americas
# 54   Argentina  Americas
# ..         ...       ...
# 295      China      Asia
# 296      China      Asia
# 297      China      Asia
# 298      China      Asia
# 299      China      Asia
#
# [250 rows x 2 columns]

# %%
subset.loc[[1,2],["country"]]
# Out:
#        country
# 1  Afghanistan
# 2  Afghanistan

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df["continent"].unique()
#retorna os valores unicos de uma coluna
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', 'Oceania'], dtype=object)

# %%
siglas = {
    "Asia": "AS",
    "Europe":"EU",
    "Africa":"AF",
    "Americas":"AM",
    "Oceania":"OC"
}

# %%
subset.insert(0, "Sigla",subset["continent"].map(siglas) )

# %%
subset
# Out:
#      Sigla      country continent  year
# 0       AS  Afghanistan      Asia  1952
# 1       AS  Afghanistan      Asia  1957
# 2       AS  Afghanistan      Asia  1962
# 3       AS  Afghanistan      Asia  1967
# 4       AS  Afghanistan      Asia  1972
# ...    ...          ...       ...   ...
# 1699    AF     Zimbabwe    Africa  1987
# 1700    AF     Zimbabwe    Africa  1992
# 1701    AF     Zimbabwe    Africa  1997
# 1702    AF     Zimbabwe    Africa  2002
# 1703    AF     Zimbabwe    Africa  2007
#
# [1704 rows x 4 columns]

# %%
subset.pop(["continent"]) #exclui uma por vez

# %%
subset
# Out:
#      Sigla      country continent  year
# 0       AS  Afghanistan      Asia  1952
# 1       AS  Afghanistan      Asia  1957
# 2       AS  Afghanistan      Asia  1962
# 3       AS  Afghanistan      Asia  1967
# 4       AS  Afghanistan      Asia  1972
# ...    ...          ...       ...   ...
# 1699    AF     Zimbabwe    Africa  1987
# 1700    AF     Zimbabwe    Africa  1992
# 1701    AF     Zimbabwe    Africa  1997
# 1702    AF     Zimbabwe    Africa  2002
# 1703    AF     Zimbabwe    Africa  2007
#
# [1704 rows x 4 columns]

# %%
subset.drop(["Sigla", "country"], axis=1) #exclui mais de uma
# Out:
#      continent  year
# 0         Asia  1952
# 1         Asia  1957
# 2         Asia  1962
# 3         Asia  1967
# 4         Asia  1972
# ...        ...   ...
# 1699    Africa  1987
# 1700    Africa  1992
# 1701    Africa  1997
# 1702    Africa  2002
# 1703    Africa  2007
#
# [1704 rows x 2 columns]

# %%
#consultas -< query()

# %%
subset
# Out:
#      Sigla      country continent  year
# 0       AS  Afghanistan      Asia  1952
# 1       AS  Afghanistan      Asia  1957
# 2       AS  Afghanistan      Asia  1962
# 3       AS  Afghanistan      Asia  1967
# 4       AS  Afghanistan      Asia  1972
# ...    ...          ...       ...   ...
# 1699    AF     Zimbabwe    Africa  1987
# 1700    AF     Zimbabwe    Africa  1992
# 1701    AF     Zimbabwe    Africa  1997
# 1702    AF     Zimbabwe    Africa  2002
# 1703    AF     Zimbabwe    Africa  2007
#
# [1704 rows x 4 columns]
